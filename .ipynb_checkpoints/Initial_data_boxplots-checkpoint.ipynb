# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('qualtrics_02_04.csv')

# %%
data = pd.read_csv('qualtrics_02_28.csv')

# %%
data.columns[2:]
# Out:
# Index([u'This voice agent made me feel: - Successful.',
#        u'This voice agent made me feel: - Frustrated.',
#        u'This voice agent made me feel: - Helped.',
#        u'This voice agent made me feel: - Efficient.',
#        u'This voice agent made me feel: - Happy.',
#        u'This voice agent made me feel: - Agile.',
#        u'This voice agent made me feel: - Pragmatic.',
#        u'This voice agent was: - Extraverted, enthusiastic.',
#        u'This voice agent was: - Critical, quarrelsome.',
#        u'This voice agent was: - Dependable, self-disciplined.',
#        u'This voice agent was: - Anxious, easily upset.',
#        u'This voice agent was: - Open to new experiences, complex.',
#        u'This voice agent was: - Reserved, quiet.',
#        u'This voice agent was: - Sympathetic, warm.',
#        u'This voice agent was: - Disorganized, careless.',
#        u'This voice agent was: - Calm, emotionally stable.',
#        u'This voice agent was: - Conventional, uncreative.',
#        u'This voice agent was: - Smart.',
#        u'This voice agent was: - Trustworthy.',
#        u'This voice agent was: - Likeable.',
#        u'This voice agent was: - Pragmatic.',
#        u'This voice agent was: - Helpful.',
#        u'Did this voice agent ever make a mistake?',
#        u'Did this agent ever try to repair a mistake it made?',
#        u'A voice agent that always tried to correct itself after a mistake ... - ... would annoy me',
#        u'A voice agent that always tried to correct itself after a mistake ... - ... would waste my time',
#        u'A voice agent that always tried to correct itself after a mistake ... - ... would improve the conversation quality',
#        u'A voice agent that always tried to correct itself after a mistake ... - ... would help me feel less frustrated'],
#       dtype='object')

# %%
print('condition one: ' + str(len(data[data[data.columns[1]]==1])) + ' participants')
print('condition two: ' + str(len(data[data[data.columns[1]]==2])) + ' participants')
print('condition three: ' + str(len(data[data[data.columns[1]]==3])) + ' participants')
print('condition four: ' + str(len(data[data[data.columns[1]]==4])) + ' participants')
# Out:
# condition one: 13 participants
# condition two: 13 participants
# condition three: 13 participants
# condition four: 11 participants

# %%
by_rep = pd.Series("No-repair(Conditon 1 and 2)" if (i==1) or (i==2) else "Repair(Condition 3 and 4)" for i in data['Participant study:'])
data['repair'] = by_rep

# %% [markdown]
# # Repair vs No-Repair

# %%
for col in data.columns[2:30]:
    fig, ax = plt.subplots(figsize=(10,8))
    plt.suptitle('')
    ax.set_xlim([1, 3])
    ax.set_ylim([0, 10])
    data.boxplot(column=[col],by =data.columns[30],ax=ax, patch_artist=True)
# Out:
# /home/bg0914/Envs/venv/local/lib/python2.7/site-packages/matplotlib/pyplot.py:522: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %% [markdown]
# # By Participants

# %%
for col in data.columns[2:30]:
    fig, ax = plt.subplots(figsize=(10,8))
    plt.suptitle('')
    ax.set_xlim([1, 3])
    ax.set_ylim([0, 10])
    data.boxplot(column=[col],by=data.columns[1], ax=ax, patch_artist=True)
